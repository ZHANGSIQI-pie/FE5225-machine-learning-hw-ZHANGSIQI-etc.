# %%
import requests
import json
import pprint
import pandas as pd
import numpy
import matplotlib.pyplot as plt

response = requests.get("https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json")
content = response.content
json_tree = json.loads(content)
pprint.pprint(json_tree)

for bike_rent_records in json_tree:
    leftRatio = float(bike_rent_records["sbi"]) / float(bike_rent_records["tot"]) * 100
    print("ID:{0} Left:{2:0.1f}% Name:{1}".format(bike_rent_records["sno"], bike_rent_records["aren"], leftRatio))
# Out:
# [{'act': '1',
#   'ar': '新北市新店區中正路700巷3號',
#   'aren': 'No. 3, Lane 700 Chung Cheng Road, Xindian District',
#   'bemp': '16',
#   'lat': '24.99116',
#   'lng': '121.53398',
#   'mday': '20210311191424',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '22',
#   'sna': '大鵬華城',
#   'snaen': 'Dapeng Community',
#   'sno': '1001',
#   'tot': '38'},
#  {'act': '1',
#   'ar': '南昌街/新昌路口(西側廣場)',
#   'aren': 'Nanchang St./Xinchang Rd.',
#   'bemp': '46',
#   'lat': '25.068914',
#   'lng': '121.662748',
#   'mday': '20210311191422',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '8',
#   'sna': '汐止火車站',
#   'snaen': 'Xizhi Railway Station',
#   'sno': '1002',
#   'tot': '56'},
#  {'act': '1',
#   'ar': '新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)',
#   'aren': 'Sec. 1, Xintai 5th Rd./Ren’ai Rd.',
#   'bemp': '26',
#   'lat': '25.064162',
#   'lng': '121.658301',
#   'mday': '20210311191435',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '20',
#   'sna': '汐止區公所',
#   'snaen': 'Xizhi Dist. Office',
#   'sno': '1003',
#   'tot': '46'},
#  {'act': '1',
#   'ar': '建成路78號對面停車場',
#   'aren': 'No78, Jiancheng Rd',
#   'bemp': '34',
#   'lat': '25.07315',
#   'lng': '121.662555',
#   'mday': '20210311191417',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '22',
#   'sna': '國泰綜合醫院',
#   'snaen': 'Cathay General Hospital',
#   'sno': '1004',
#   'tot': '56'},
#  {'act': '1',
#   'ar': '寶中路/品牌路口(東南側)',
#   'aren': 'Baozhong Rd./',
#   'bemp': '7',
#   'lat': '24.979649',
#   'lng': '121.546319',
#   'mday': '20210311191439',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '33',
#   'sna': '裕隆公園',
#   'snaen': 'Yulon Park',
#   'sno': '1005',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '中興路三段224號(對面)',
#   'aren': 'No. 224, Sec. 3, Zhongxing Rd., Xindian Dist.(opposite)',
#   'bemp': '50',
#   'lat': '24.982830',
#   'lng': '121.543620',
#   'mday': '20210311191441',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '44',
#   'sna': '捷運大坪林站(5號出口)',
#   'snaen': 'MRT DaPingLin Station(Exit.5)',
#   'sno': '1006',
#   'tot': '94'},
#  {'act': '1',
#   'ar': '大同路二段184巷/龍安路202巷(西側)(汐科火車站北站出口前)',
#   'aren': 'Ln. 184,Sec. 2, Datong Rd./Ln. 202,Long’an Rd.',
#   'bemp': '24',
#   'lat': '25.064106',
#   'lng': '121.653019',
#   'mday': '20210311191433',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '10',
#   'sna': '汐科火車站(北)',
#   'snaen': 'Xike Railway Station(North)',
#   'sno': '1007',
#   'tot': '34'},
#  {'act': '1',
#   'ar': '重陽路一段120巷/中華路2巷',
#   'aren': 'Ln. 120, Sec. 1, Chongyang Rd./Ln. 2, Zhonghua Rd.',
#   'bemp': '25',
#   'lat': '25.060125',
#   'lng': '121.483101',
#   'mday': '20210311191431',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '15',
#   'sna': '興華公園',
#   'snaen': 'Xinghua Park',
#   'sno': '1008',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '集美街/重新路四段184巷',
#   'aren': 'Jimei St., Sanchong Dist./Ln. 184, Sec. 4, Chongxin Rd.',
#   'bemp': '45',
#   'lat': '25.054391',
#   'lng': '121.488489',
#   'mday': '20210311191417',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '23',
#   'sna': '三重國民運動中心',
#   'snaen': 'San chong Civil Sports Center',
#   'sno': '1009',
#   'tot': '68'},
#  {'act': '1',
#   'ar': '捷運路/捷運路37巷',
#   'aren': 'Jieyun Rd./Ln. 37, Jieyun Rd.',
#   'bemp': '29',
#   'lat': '25.055883',
#   'lng': '121.484739',
#   'mday': '20210311191416',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '5',
#   'sna': '捷運三重站(3號出口)',
#   'snaen': 'MRT Sanchong Sta. (Exit 3)',
#   'sno': '1010',
#   'tot': '34'},
#  {'act': '1',
#   'ar': '樟樹二路/樟樹一路141巷',
#   'aren': 'Zhangshu 2nd Rd./Ln. 141, Zhangshu 1st Rd.',
#   'bemp': '28',
#   'lat': '25.066688',
#   'lng': '121.640367',
#   'mday': '20210311191445',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '20',
#   'sna': '樟樹國小',
#   'snaen': 'Zhangshu Elementary School',
#   'sno': '1011',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '中興路/民族六街',
#   'aren': 'Zhongxing Rd./Minzu 6th St.',
#   'bemp': '39',
#   'lat': '25.0688',
#   'lng': '121.628908',
#   'mday': '20210311191431',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '13',
#   'sna': '金龍國小',
#   'snaen': 'Jinlong Elementary School',
#   'sno': '1012',
#   'tot': '52'},
#  {'act': '0',
#   'ar': '民權街二段90號',
#   'aren': 'No.90, Sec. 2, Minquan St.',
#   'bemp': '0',
#   'lat': '25.047578',
#   'lng': '121.618888',
#   'mday': '20210106092234',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '0',
#   'sna': '白雲國小',
#   'snaen': 'Pai Yun Primary School',
#   'sno': '1013',
#   'tot': '46'},
#  {'act': '1',
#   'ar': '東勢街/芳園街',
#   'aren': 'Dongshi St./Fangyuan St.',
#   'bemp': '41',
#   'lat': '25.039031',
#   'lng': '121.624333',
#   'mday': '20210311191445',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '11',
#   'sna': '東勢宜興活動中心',
#   'snaen': 'Yixing-Dongshi Civic Center',
#   'sno': '1014',
#   'tot': '52'},
#  {'act': '1',
#   'ar': '建安街/建安街57巷',
#   'aren': 'Ln. 57, Jian’an St./Jian’an St.',
#   'bemp': '29',
#   'lat': '25.025358',
#   'lng': '121.428348',
#   'mday': '20210311191441',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '11',
#   'sna': '後港公園',
#   'snaen': 'Hougang Park',
#   'sno': '1015',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '四維路17號-20號',
#   'aren': 'No.17, Siwei Rd./No.20, Siwei Rd.',
#   'bemp': '22',
#   'lat': '25.0241250',
#   'lng': '121.423870',
#   'mday': '20210311191420',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '20',
#   'sna': '福營行政中心',
#   'snaen': 'Fuying Administration Center',
#   'sno': '1016',
#   'tot': '42'},
#  {'act': '1',
#   'ar': '新莊區西盛街/西盛街201巷',
#   'aren': 'Xisheng St./Ln. 201, Xisheng St.',
#   'bemp': '17',
#   'lat': '25.017113',
#   'lng': '121.428048',
#   'mday': '20210311191416',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '19',
#   'sna': '西盛公園',
#   'snaen': 'Xisheng Park',
#   'sno': '1017',
#   'tot': '36'},
#  {'act': '1',
#   'ar': '北新路二段/北新路二段97巷',
#   'aren': 'Sec. 2, Beixin Rd./Ln. 97, Sec. 2, Beixin Rd.',
#   'bemp': '14',
#   'lat': '24.974272',
#   'lng': '121.542779',
#   'mday': '20210311191435',
#   'sarea': '新店區',
#   'sareaen': 'Xindian Dist.',
#   'sbi': '23',
#   'sna': '忠誠里(北新路2段97巷)',
#   'snaen': 'Zhongcheng Village (Ln. 97, Sec. 2, Beixin Rd)',
#   'sno': '1018',
#   'tot': '40'},
#  {'act': '1',
#   'ar': '民權路139號旁',
#   'aren': 'No.139, Minquan Rd.',
#   'bemp': '30',
#   'lat': '25.090565',
#   'lng': '121.471621',
#   'mday': '20210311191439',
#   'sarea': '蘆洲區',
#   'sareaen': 'Luzhou Dist.',
#   'sbi': '20',
#   'sna': '仁愛廣場',
#   'snaen': 'Renai Square',
#   'sno': '1019',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '中正北路/三民街175巷',
#   'aren': 'Zhongzheng N. Rd./Ln. 175, Sanmin St.',
#   'bemp': '23',
#   'lat': '25.066245 ',
#   'lng': '121.484337 ',
#   'mday': '20210311191417',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '13',
#   'sna': '重陽國小',
#   'snaen': 'Chong Yang Elementary School',
#   'sno': '1020',
#   'tot': '42'},
#  {'act': '1',
#   'ar': '中正北路107號',
#   'aren': 'No.107, Zhongzheng N. Rd',
#   'bemp': '49',
#   'lat': '25.063396',
#   'lng': '121.488982',
#   'mday': '20210311191419',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '1',
#   'sna': '明志國中',
#   'snaen': 'Mingzhi Junior High School',
#   'sno': '1021',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '中正北路/中正北路276巷',
#   'aren': 'Ln. 276, Zhongzheng N. Rd.',
#   'bemp': '57',
#   'lat': '25.068681',
#   'lng': '121.480705',
#   'mday': '20210311191430',
#   'sarea': '三重區',
#   'sareaen': 'Sanchong Dist.',
#   'sbi': '7',
#   'sna': '三重商工',
#   'snaen': 'San-Chung Commercial and Industrial Vocational High School',
#   'sno': '1022',
#   'tot': '64'},
#  {'act': '1',
#   'ar': '中正路/中華路一段(鄰近新莊廟街)',
#   'aren': 'Zhongzheng Rd./Sec. 1, Zhonghua Rd.',
#   'bemp': '56',
#   'lat': '25.036152 ',
#   'lng': '121.452069 ',
#   'mday': '20210311191442',
#   'sarea': '新莊區',
#   'sareaen': 'Xinzhuang Dist.',
#   'sbi': '0',
#   'sna': '捷運新莊站(1號出口)',
#   'snaen': 'MRT Xinzhuang Sta. (Exit 1)',
#   'sno': '1023',
#   'tot': '58'},
#  {'act': '1',
#   'ar': '原興路/中興路150巷',
#   'aren': 'Yuanxing Rd./Ln. 150, Zhongxing Rd.',
#   'bemp': '16',
#   'lat': '25.065042',
#   'lng': '121.633149',
#   'mday': '20210311191433',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '36',
#   'sna': '原興廣場',
#   'snaen': 'Yuan Xing Square',
#   'sno': '1024',
#   'tot': '52'},
#  {'act': '1',
#   'ar': '水源路二段42號訖水源路二段68號',
#   'aren': 'No.42 to No.68, Sec. 2, Shuiyuan Rd.',
#   'bemp': '46',
#   'lat': '25.056875',
#   'lng': '121.655207',
#   'mday': '20210311191442',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist.',
#   'sbi': '30',
#   'sna': '文化白雲公園',
#   'snaen': 'Wenhua-Baiyun Park',
#   'sno': '1025',
#   'tot': '76'},
#  {'act': '1',
#   'ar': '更生街/自立路(西南側)',
#   'aren': 'Gengsheng St./Zili Rd.',
#   'bemp': '43',
#   'lat': '24.996151 ',
#   'lng': '121.521988 ',
#   'mday': '20210311191434',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '19',
#   'sna': '秀山國小',
#   'snaen': 'Xiushan Elementary School',
#   'sno': '1026',
#   'tot': '62'},
#  {'act': '1',
#   'ar': '中安街/中和路378巷(東南側)',
#   'aren': 'Zhong’an St./Ln. 378, Zhonghe Rd.',
#   'bemp': '36',
#   'lat': '25.001013 ',
#   'lng': '121.511588 ',
#   'mday': '20210311191431',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '36',
#   'sna': '捷運永安市場站',
#   'snaen': 'MRT Yongan Market Sta.',
#   'sno': '1027',
#   'tot': '72'},
#  {'act': '1',
#   'ar': '永貞路/永亨路(東南側)',
#   'aren': 'Yongzhen Rd./Yongheng Rd.',
#   'bemp': '42',
#   'lat': '25.005952',
#   'lng': '121.520930',
#   'mday': '20210311191424',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist.',
#   'sbi': '23',
#   'sna': '福和國中',
#   'snaen': 'Fuhe Junior High School',
#   'sno': '1028',
#   'tot': '66'},
#  {'act': '1',
#   'ar': '仁愛路/保生路(鄰近世界宗教博物館)',
#   'aren': 'Ren’ai Rd./Baosheng Rd.',
#   'bemp': '50',
#   'lat': '25.009838',
#   'lng': '121.505825',
#   'mday': '20210311191432',
#   'sarea': '永和區',
#   'sareaen': 'Yonghe Dist.',
#   'sbi': '9',
#   'sna': '仁愛公園',
#   'snaen': 'Renai Park',
#   'sno': '1029',
#   'tot': '60'},
#  {'act': '1',
#   'ar': '安樂路/得和路(西南側)',
#   'aren': 'Anle Rd./Dehe Rd.',
#   'bemp': '28',
#   'lat': '25.000726 ',
#   'lng': '121.514350 ',
#   'mday': '20210311191441',
#   'sarea': '中和區',
#   'sareaen': 'Zhonghe Dist.',
#   'sbi': '16',
#   'sna': '中和公園',
#   'snaen': 'Zhonghe Park',
#   'sno': '1030',
#   'tot': '46'}]
# ID:1001 Left:57.9% Name:No. 3, Lane 700 Chung Cheng Road, Xindian District
# ID:1002 Left:14.3% Name:Nanchang St./Xinchang Rd.
# ID:1003 Left:43.5% Name:Sec. 1, Xintai 5th Rd./Ren’ai Rd.
# ID:1004 Left:39.3% Name:No78, Jiancheng Rd
# ID:1005 Left:82.5% Name:Baozhong Rd./
# ID:1006 Left:46.8% Name:No. 224, Sec. 3, Zhongxing Rd., Xindian Dist.(opposite)
# ID:1007 Left:29.4% Name:Ln. 184,Sec. 2, Datong Rd./Ln. 202,Long’an Rd.
# ID:1008 Left:37.5% Name:Ln. 120, Sec. 1, Chongyang Rd./Ln. 2, Zhonghua Rd.
# ID:1009 Left:33.8% Name:Jimei St., Sanchong Dist./Ln. 184, Sec. 4, Chongxin Rd.
# ID:1010 Left:14.7% Name:Jieyun Rd./Ln. 37, Jieyun Rd.
# ID:1011 Left:41.7% Name:Zhangshu 2nd Rd./Ln. 141, Zhangshu 1st Rd.
# ID:1012 Left:25.0% Name:Zhongxing Rd./Minzu 6th St.
# ID:1013 Left:0.0% Name:No.90, Sec. 2, Minquan St.
# ID:1014 Left:21.2% Name:Dongshi St./Fangyuan St.
# ID:1015 Left:27.5% Name:Ln. 57, Jian’an St./Jian’an St.
# ID:1016 Left:47.6% Name:No.17, Siwei Rd./No.20, Siwei Rd.
# ID:1017 Left:52.8% Name:Xisheng St./Ln. 201, Xisheng St.
# ID:1018 Left:57.5% Name:Sec. 2, Beixin Rd./Ln. 97, Sec. 2, Beixin Rd.
# ID:1019 Left:40.0% Name:No.139, Minquan Rd.
# ID:1020 Left:31.0% Name:Zhongzheng N. Rd./Ln. 175, Sanmin St.
# ID:1021 Left:2.0% Name:No.107, Zhongzheng N. Rd
# ID:1022 Left:10.9% Name:Ln. 276, Zhongzheng N. Rd.
# ID:1023 Left:0.0% Name:Zhongzheng Rd./Sec. 1, Zhonghua Rd.
# ID:1024 Left:69.2% Name:Yuanxing Rd./Ln. 150, Zhongxing Rd.
# ID:1025 Left:39.5% Name:No.42 to No.68, Sec. 2, Shuiyuan Rd.
# ID:1026 Left:30.6% Name:Gengsheng St./Zili Rd.
# ID:1027 Left:50.0% Name:Zhong’an St./Ln. 378, Zhonghe Rd.
# ID:1028 Left:34.8% Name:Yongzhen Rd./Yongheng Rd.
# ID:1029 Left:15.0% Name:Ren’ai Rd./Baosheng Rd.
# ID:1030 Left:34.8% Name:Anle Rd./Dehe Rd.

# %%
dataframe = pd.DataFrame(json_tree)

# %%
dataframe
# Out:
#      sno            sna tot sbi sarea            mday         lat  \
# 0   1001           大鵬華城  38  22   新店區  20210311191424    24.99116
# 1   1002          汐止火車站  56   8   汐止區  20210311191422   25.068914
# 2   1003          汐止區公所  46  20   汐止區  20210311191435   25.064162
# 3   1004         國泰綜合醫院  56  22   汐止區  20210311191417    25.07315
# 4   1005           裕隆公園  40  33   新店區  20210311191439   24.979649
# 5   1006   捷運大坪林站(5號出口)  94  44   新店區  20210311191441   24.982830
# 6   1007       汐科火車站(北)  34  10   汐止區  20210311191433   25.064106
# 7   1008           興華公園  40  15   三重區  20210311191431   25.060125
# 8   1009       三重國民運動中心  68  23   三重區  20210311191417   25.054391
# 9   1010    捷運三重站(3號出口)  34   5   三重區  20210311191416   25.055883
# 10  1011           樟樹國小  48  20   汐止區  20210311191445   25.066688
# 11  1012           金龍國小  52  13   汐止區  20210311191431     25.0688
# 12  1013           白雲國小  46   0   汐止區  20210106092234   25.047578
# 13  1014       東勢宜興活動中心  52  11   汐止區  20210311191445   25.039031
# 14  1015           後港公園  40  11   新莊區  20210311191441   25.025358
# 15  1016         福營行政中心  42  20   新莊區  20210311191420  25.0241250
# 16  1017           西盛公園  36  19   新莊區  20210311191416   25.017113
# 17  1018  忠誠里(北新路2段97巷)  40  23   新店區  20210311191435   24.974272
# 18  1019           仁愛廣場  50  20   蘆洲區  20210311191439   25.090565
# 19  1020           重陽國小  42  13   三重區  20210311191417  25.066245
# 20  1021           明志國中  50   1   三重區  20210311191419   25.063396
# 21  1022           三重商工  64   7   三重區  20210311191430   25.068681
# 22  1023    捷運新莊站(1號出口)  58   0   新莊區  20210311191442  25.036152
# 23  1024           原興廣場  52  36   汐止區  20210311191433   25.065042
# 24  1025         文化白雲公園  76  30   汐止區  20210311191442   25.056875
# 25  1026           秀山國小  62  19   中和區  20210311191434  24.996151
# 26  1027        捷運永安市場站  72  36   中和區  20210311191431  25.001013
# 27  1028           福和國中  66  23   永和區  20210311191424   25.005952
# 28  1029           仁愛公園  60   9   永和區  20210311191432   25.009838
# 29  1030           中和公園  46  16   中和區  20210311191441  25.000726
#
#             lng                                 ar          sareaen  \
# 0     121.53398                    新北市新店區中正路700巷3號    Xindian Dist.
# 1    121.662748                     南昌街/新昌路口(西側廣場)      Xizhi Dist.
# 2    121.658301    新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)      Xizhi Dist.
# 3    121.662555                        建成路78號對面停車場      Xizhi Dist.
# 4    121.546319                      寶中路/品牌路口(東南側)    Xindian Dist.
# 5    121.543620                      中興路三段224號(對面)    Xindian Dist.
# 6    121.653019  大同路二段184巷/龍安路202巷(西側)(汐科火車站北站出口前)      Xizhi Dist.
# 7    121.483101                    重陽路一段120巷/中華路2巷   Sanchong Dist.
# 8    121.488489                      集美街/重新路四段184巷   Sanchong Dist.
# 9    121.484739                         捷運路/捷運路37巷   Sanchong Dist.
# 10   121.640367                      樟樹二路/樟樹一路141巷      Xizhi Dist.
# 11   121.628908                           中興路/民族六街      Xizhi Dist.
# 12   121.618888                           民權街二段90號      Xizhi Dist.
# 13   121.624333                            東勢街/芳園街      Xizhi Dist.
# 14   121.428348                         建安街/建安街57巷  Xinzhuang Dist.
# 15   121.423870                         四維路17號-20號  Xinzhuang Dist.
# 16   121.428048                     新莊區西盛街/西盛街201巷  Xinzhuang Dist.
# 17   121.542779                     北新路二段/北新路二段97巷    Xindian Dist.
# 18   121.471621                           民權路139號旁     Luzhou Dist.
# 19  121.484337                        中正北路/三民街175巷   Sanchong Dist.
# 20   121.488982                           中正北路107號   Sanchong Dist.
# 21   121.480705                      中正北路/中正北路276巷   Sanchong Dist.
# 22  121.452069                   中正路/中華路一段(鄰近新莊廟街)  Xinzhuang Dist.
# 23   121.633149                        原興路/中興路150巷      Xizhi Dist.
# 24   121.655207                  水源路二段42號訖水源路二段68號      Xizhi Dist.
# 25  121.521988                        更生街/自立路(西南側)    Zhonghe Dist.
# 26  121.511588                    中安街/中和路378巷(東南側)    Zhonghe Dist.
# 27   121.520930                       永貞路/永亨路(東南側)     Yonghe Dist.
# 28   121.505825                 仁愛路/保生路(鄰近世界宗教博物館)     Yonghe Dist.
# 29  121.514350                        安樂路/得和路(西南側)    Zhonghe Dist.
#
#                                                 snaen  \
# 0                                    Dapeng Community
# 1                               Xizhi Railway Station
# 2                                  Xizhi Dist. Office
# 3                             Cathay General Hospital
# 4                                          Yulon Park
# 5                       MRT DaPingLin Station(Exit.5)
# 6                         Xike Railway Station(North)
# 7                                        Xinghua Park
# 8                       San chong Civil Sports Center
# 9                          MRT Sanchong Sta. (Exit 3)
# 10                         Zhangshu Elementary School
# 11                          Jinlong Elementary School
# 12                             Pai Yun Primary School
# 13                        Yixing-Dongshi Civic Center
# 14                                       Hougang Park
# 15                       Fuying Administration Center
# 16                                       Xisheng Park
# 17     Zhongcheng Village (Ln. 97, Sec. 2, Beixin Rd)
# 18                                       Renai Square
# 19                       Chong Yang Elementary School
# 20                         Mingzhi Junior High School
# 21  San-Chung Commercial and Industrial Vocational...
# 22                        MRT Xinzhuang Sta. (Exit 1)
# 23                                   Yuan Xing Square
# 24                                 Wenhua-Baiyun Park
# 25                          Xiushan Elementary School
# 26                             MRT Yongan Market Sta.
# 27                            Fuhe Junior High School
# 28                                         Renai Park
# 29                                       Zhonghe Park
#
#                                                  aren bemp act
# 0   No. 3, Lane 700 Chung Cheng Road, Xindian Dist...   16   1
# 1                           Nanchang St./Xinchang Rd.   46   1
# 2                   Sec. 1, Xintai 5th Rd./Ren’ai Rd.   26   1
# 3                                  No78, Jiancheng Rd   34   1
# 4                                       Baozhong Rd./    7   1
# 5   No. 224, Sec. 3, Zhongxing Rd., Xindian Dist.(...   50   1
# 6      Ln. 184,Sec. 2, Datong Rd./Ln. 202,Long’an Rd.   24   1
# 7   Ln. 120, Sec. 1, Chongyang Rd./Ln. 2, Zhonghua...   25   1
# 8   Jimei St., Sanchong Dist./Ln. 184, Sec. 4, Cho...   45   1
# 9                       Jieyun Rd./Ln. 37, Jieyun Rd.   29   1
# 10         Zhangshu 2nd Rd./Ln. 141, Zhangshu 1st Rd.   28   1
# 11                        Zhongxing Rd./Minzu 6th St.   39   1
# 12                         No.90, Sec. 2, Minquan St.    0   0
# 13                           Dongshi St./Fangyuan St.   41   1
# 14                    Ln. 57, Jian’an St./Jian’an St.   29   1
# 15                  No.17, Siwei Rd./No.20, Siwei Rd.   22   1
# 16                   Xisheng St./Ln. 201, Xisheng St.   17   1
# 17      Sec. 2, Beixin Rd./Ln. 97, Sec. 2, Beixin Rd.   14   1
# 18                                No.139, Minquan Rd.   30   1
# 19              Zhongzheng N. Rd./Ln. 175, Sanmin St.   23   1
# 20                           No.107, Zhongzheng N. Rd   49   1
# 21                         Ln. 276, Zhongzheng N. Rd.   57   1
# 22                Zhongzheng Rd./Sec. 1, Zhonghua Rd.   56   1
# 23                Yuanxing Rd./Ln. 150, Zhongxing Rd.   16   1
# 24               No.42 to No.68, Sec. 2, Shuiyuan Rd.   46   1
# 25                             Gengsheng St./Zili Rd.   43   1
# 26                  Zhong’an St./Ln. 378, Zhonghe Rd.   36   1
# 27                          Yongzhen Rd./Yongheng Rd.   42   1
# 28                            Ren’ai Rd./Baosheng Rd.   50   1
# 29                                  Anle Rd./Dehe Rd.   28   1

# %%
dataframe['lat']=dataframe['lat'].astype(float)
dataframe['lng']=dataframe['lng'].astype(float)
dataframe['sbi']=dataframe['sbi'].astype(float)
w = dataframe['lat']
v = dataframe['lng']
k = dataframe['sbi']
plt.scatter(w, v, k)
plt.title('Scatter plot of Taipei U-bike')
plt.xlabel('lat')
plt.ylabel('long')
plt.show()

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np
import matplotlib.pyplot as plt
import descartes
u_bike = folium.Map(location= [25.0330, 121.5654], zoom_start=10)
u_bike
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0b9e9e030cea464daffda7cea9e600a4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0b9e9e030cea464daffda7cea9e600a4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0b9e9e030cea464daffda7cea9e600a4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0b9e9e030cea464daffda7cea9e600a4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B25.033%2C%20121.5654%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
dataframe['sbi']=dataframe['sbi'].astype(str)
for i in range(0,20):
  folium.Marker([dataframe['lat'][i], dataframe['lng'][i]], popup= dataframe['sbi'][i]). add_to(u_bike)
u_bike
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba4604574133> in <module>
# ----> 1 dataframe['sbi']=dataframe['sbi'].astype(str)
#       2 for i in range(0,20):
#       3   folium.Marker([dataframe['lat'][i], dataframe['lng'][i]], popup= dataframe['sbi'][i]). add_to(u_bike)
#       4 u_bike
#
# NameError: name 'dataframe' is not defined
